# %%
# import time
# import random 

# def move(row, col, rv, cv):
#     if _input[row][col] == "<":
#             rv, cv = 0, -1
#     elif _input[row][col] ==  ">":
#             rv, cv =0, 1
#     elif _input[row][col] ==  "^":
#             rv, cv = -1, 0
#     elif _input[row][col] ==  "v":
#             rv, cv = 1, 0
#     elif _input[row][col] ==  "_":
#             if _input[0][0] == 0:
#                 rv, cv = 0, 1
#             else:
#                 rv, cv = 0, -1
#     elif _input[row][col] ==  "|":
#             if _input[0][0] == 0:
#                 rv, cv = 1, 0
#             else:
#                 rv, cv = -1, 0
#     elif _input[row][col] ==  "?":
#             rv, cv = rand_vector[random.randint(0, 3)]
#     elif _input[row][col] ==  ".":
#             rv, cv = -1000, -1000
#     elif _input[row][col] ==  "@":
#             rv, cv = 1000, 1000
#     elif _input[row][col] ==  "+":
#             if _input[0][0] == 15:
#                 _input[0][0] = 0
#             else:
#                 _input[0][0] += 1
#     elif _input[row][col] ==  "-":
#             if _input[0][0] == 0:
#                 _input[0][0] = 15
#             else:
#                 _input[0][0] -= 1
#     else:
#             _input[0][0] = _input[row][col]
#     return row, col, rv, cv


# n = int(input())
# rand_vector = [[0, -1], [0, 1], [-1, 0], [1, 0]]

# for i in range(n):
# # for i in range(1):
#     r, c= map(int, input().split())
#     _input = [list(input()) for _ in range(r)]
#     _input[0][0] = int(_input[0][0]) if _input[0][0].isdigit() else 0
#     row, col, rv, cv = 0, 1, 0, 1
#     break_flag = False
#     start_time = time.time()
#     max_duration = 1
#     while _input[row][col] != "@":
#         if time.time() - start_time > max_duration:
#             break_flag = True
#             break
#         if row == r-1 and rv == 1:
#             row = -1
#         elif row == 0 and rv == -1:
#             row = r
#         elif col == c-1 and cv == 1:
#             cv = -1
#         elif col == 0 and cv == -1:
#             cv = c
#         row, col, rv, cv = move(row+rv, col+cv, rv, cv)
#         if row == -1000:
#             break_flag = True
#             break
#         elif row == 1000:
#             break
#     print(f"#{i} NO") if break_flag else print(f"#{i} YES")

try:
    print(e)
except Exception as e:
    print(e)
# Out:
# name 'e' is not defined

# %%
import time
import random 

def move(row, col, rv, cv):
    if _input[row][col] == "<":
            rv, cv = 0, -1
    elif _input[row][col] ==  ">":
            rv, cv =0, 1
    elif _input[row][col] ==  "^":
            rv, cv = -1, 0
    elif _input[row][col] ==  "v":
            rv, cv = 1, 0
    elif _input[row][col] ==  "_":
            if _input[0][0] == 0:
                rv, cv = 0, 1
            else:
                rv, cv = 0, -1
    elif _input[row][col] ==  "|":
            if _input[0][0] == 0:
                rv, cv = 1, 0
            else:
                rv, cv = -1, 0
    elif _input[row][col] ==  "?":
            rv, cv = rand_vector[random.randint(0, 3)]
    elif _input[row][col] ==  ".":
            rv, cv = -1000, -1000
    elif _input[row][col] ==  "@":
            rv, cv = 1000, 1000
    elif _input[row][col] ==  "+":
            if _input[0][0] == 15:
                _input[0][0] = 0
            else:
                _input[0][0] += 1
    elif _input[row][col] ==  "-":
            if _input[0][0] == 0:
                _input[0][0] = 15
            else:
                _input[0][0] -= 1
    else:
            _input[0][0] = _input[row][col]
    if row == r-1 and rv == 1:
        row = 0
    elif row == 0 and rv == -1:
        row = r-1
    elif col == c-1 and cv == 1:
        cv = 0
    elif col == 0 and cv == -1:
        cv = c-1
    return row, col, rv, cv
n = int(input())
rand_vector = [[0, -1], [0, 1], [-1, 0], [1, 0]]

for i in range(1, n+1):
    r, c= map(int, input().split())
    _input = [list(input()) for _ in range(r)]
    _input[0][0] = int(_input[0][0]) if _input[0][0].isdigit() else 0
    row, col, rv, cv = 0, 1, 0, 1
    break_flag = False
    start_time = time.time()
    max_duration = 1
    while _input[row][col] != "@":
        if time.time() - start_time > max_duration:
            break_flag = True
            break
        row, col, rv, cv = move(row+rv, col+cv, rv, cv)
        if rv == -1000:
            break_flag = True
            break
        elif rv == 1000:
            break
    print(f"#{i} NO") if break_flag else print(f"#{i} YES")
# Out:
# [[0, '>', '-', '-', 'v', '.'], ['.', '^', '-', '-', '_', '@']]

# %%
import time
import random 

def move(row, col, rv, cv):
    if _input[row][col] == "<":
            rv, cv = 0, -1
    elif _input[row][col] ==  ">":
            rv, cv =0, 1
    elif _input[row][col] ==  "^":
            rv, cv = -1, 0
    elif _input[row][col] ==  "v":
            rv, cv = 1, 0
    elif _input[row][col] ==  "_":
            if _input[0][0] == 0:
                rv, cv = 0, 1
            else:
                rv, cv = 0, -1
    elif _input[row][col] ==  "|":
            if _input[0][0] == 0:
                rv, cv = 1, 0
            else:
                rv, cv = -1, 0
    elif _input[row][col] ==  "?":
            rv, cv = rand_vector[random.randint(0, 3)]
    elif _input[row][col] ==  ".":
            rv, cv = -1000, -1000
    elif _input[row][col] ==  "@":
            rv, cv = 1000, 1000
    elif _input[row][col] ==  "+":
            if _input[0][0] == 15:
                _input[0][0] = 0
            else:
                _input[0][0] += 1
    elif _input[row][col] ==  "-":
            if _input[0][0] == 0:
                _input[0][0] = 15
            else:
                _input[0][0] -= 1
    else:
            _input[0][0] = int(_input[row][col])
    if row == r-1 and rv == 1:
        row = 0
    elif row == 0 and rv == -1:
        row = r-1
    elif col == c-1 and cv == 1:
        col = 0
    elif col == 0 and cv == -1:
        col = c-1
    return row, col, rv, cv
n = int(input())
rand_vector = [[0, -1], [0, 1], [-1, 0], [1, 0]]

for i in range(1, n+1):
    r, c= map(int, input().split())
    _input = [list(input()) for _ in range(r)]
    _input[0][0] = int(_input[0][0]) if _input[0][0].isdigit() else 0
    row, col, rv, cv = 0, 1, 0, 1
    break_flag = False
    start_time = time.time()
    max_duration = 0.5
    while _input[row][col] != "@":
        if time.time() - start_time > max_duration:
            break_flag = True
            break
        row, col, rv, cv = move(row+rv, col+cv, rv, cv)
        if rv == -1000:
            break_flag = True
            break
        elif rv == 1000:
            break
    print(f"#{i} NO") if break_flag else print(f"#{i} YES")
# Out:
# [[0, '>', '-', '-', 'v', '.'], ['.', '^', '-', '-', '_', '@']]
